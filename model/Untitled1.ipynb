# %%
# import libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import pandas.io.data as web
import datetime

from p3 import *

# %%
date_range = portfolio_returns.index[portfolio_returns.index > datetime.datetime(2013,12,31,0,0)]

# %%
portfolio_returns = pd.io.parsers.read_csv('model_output/test_results.csv', index_col=0, parse_dates=True)
portfolio_returns = portfolio_returns.ix[date_range]

index_tix = ['^GSPC', '^IXIC']
index = get_collection_as_pandas_df(index_tix, 'index_test')

index = index.ix[date_range][['^GSPC',]]


index_returns = (index / index.shift(1))
portfolio_returns['index'] = index_returns

portfolio_returns_prod = portfolio_returns.cumprod()
portfolio_returns = portfolio_returns.dropna(how='any')
portfolio_returns_prod = portfolio_returns_prod.dropna(how='any')

# %%
portfolio_returns.ix[date_range][['7','index']].plot()

# %%
portfolio_returns_prod.ix[date_range][['7','index']].plot()

# %%
index.plot()

# %%
p = index.head(1)['^GSPC'].values[0]
# build list of change in prices over time
ps = [p,]
for r in portfolio_returns['index'].values:
    ps.append(r*ps[-1])
price_build_returns = pd.Series(ps, index=index['^GSPC'].index)
index['price_build_returns'] = price_build_returns

# build list of change in prices over time
ps = [p,]
for r in portfolio_returns_prod['index'].values:
    ps.append(r*p)
price_build_returns_prod = pd.Series(ps, index=index['^GSPC'].index)
index['price_build_returns_prod'] = price_build_returns_prod

index.plot()

# %%
tix = get_import_io_s_and_p_tickers()
df = get_collection_as_pandas_df(tix, 'stocks_test', update=False)
w = Window(df, start_date=datetime.datetime(2014,7,1,0,0), end_date=datetime.datetime(2014,10,1,0,0), return_period_days=1)
port = w.get_stat_arb_portfolio(return_period_days=7)
# Out:
# Could not calcualte recent performance - u'AMZN'
# Could not calcualte recent performance - u'AVGO'
# Could not calcualte recent performance - u'BBY'
# Could not calcualte recent performance - u'CRM'
# Could not calcualte recent performance - u'DG'
# Could not calcualte recent performance - u'DISCA'
# Could not calcualte recent performance - u'DISCK'
# Could not calcualte recent performance - u'FDO'
# Could not calcualte recent performance - u'GMCR'
# Could not calcualte recent performance - u'KORS'
# Could not calcualte recent performance - u'MNST'
# Could not calcualte recent performance - u'NE'
# Could not calcualte recent performance - u'NFX'
# Could not calcualte recent performance - u'PVH'
# Could not calcualte recent performance - u'SPLS'
# Could not calcualte recent performance - u'TJX'
# portfolio beta: 0.00339128127926

# %%
w.returns.tail()
# Out:
#                    A        AA      AAPL      ABBV       ABC       ABT  \
# date
# 2014-09-25  0.981539  0.983019  0.961867  0.982218  0.992952  0.985222
# 2014-09-26  0.993145  1.035829  1.029427  1.020517  0.999097  1.000238
# 2014-09-29  1.011504  0.983941  0.993648  0.988681  1.002712  0.997382
# 2014-09-30  0.997025  1.010044  1.006393  0.987013  0.995749  0.992601
# 2014-10-01  0.986311  0.975761  0.984417  0.990824  0.992109  0.990142
#
#                  ACE       ACN       ACT      ADBE    ...         XLNX  \
# date                                                  ...
# 2014-09-25  0.989774  0.984788  0.986008  0.980878    ...     0.976267
# 2014-09-26  1.003033  1.003925  1.000450  1.009600    ...     1.009116
# 2014-09-29  0.990739  1.007946  0.998978  1.012580    ...     0.995830
# 2014-09-30  1.000286  1.017518  0.987274  0.999567    ...     0.985113
# 2014-10-01  0.989988  0.980325  0.988395  0.976153    ...     0.987249
#
#                  XOM      XRAY       XRX       XYL      YHOO       YUM  \
# date
# 2014-09-25  0.983615  0.981826  0.976436  0.976726  0.976680  0.987712
# 2014-09-26  1.012520  1.007272  0.996229  1.002465  1.043902  1.011183
# 2014-09-29  0.989521  1.004157  1.002271  0.990437  0.996557  1.004424
# 2014-09-30  0.995976  0.993464  0.999245  0.979034  1.005676  0.990641
# 2014-10-01  0.987347  0.993640  0.988662  0.982249  0.989448  0.993470
#
#                 ZION       ZMH       ZTS
# date
# 2014-09-25  0.987031  0.977034  0.992346
# 2014-09-26  1.010719  1.004049  1.009091
# 2014-09-29  0.998632  0.998033  1.004368
# 2014-09-30  0.995546  0.991031  1.004349
# 2014-10-01  0.982106  1.002089  0.986468
#
# [5 rows x 500 columns]

# %%
prod = (w.returns / w.returns.shift(1)).cumprod()
prod.tail(3).ix[2] / prod.tail(3).ix[0]
# Out:
# A       0.975093
# AA      0.991687
# AAPL    0.990710
# ABBV    1.002168
# ABC     0.989425
# ABT     0.992741
# ACE     0.999242
# ACN     0.972597
# ACT     0.989406
# ADBE    0.964025
# ADI     0.979251
# ADM     0.978034
# ADP     0.857370
# ADS     0.967198
# ADSK    0.996215
# ...
# WYN     0.977424
# WYNN    1.004447
# XEC     0.964945
# XEL     1.005280
# XL      1.004511
# XLNX    0.991383
# XOM     0.997803
# XRAY    0.989527
# XRX     0.986422
# XYL     0.991732
# YHOO    0.992866
# YUM     0.989095
# ZION    0.983452
# ZMH     1.004064
# ZTS     0.982178
# Length: 500, dtype: float64

# %%
w.period_returns.tail(3).ix[2] / w.period_returns.tail(3).ix[0]
# Out:
# A       0.975093
# AA      0.991687
# AAPL    0.990710
# ABBV    1.002168
# ABC     0.989425
# ABT     0.992741
# ACE     0.999242
# ACN     0.972597
# ACT     0.989406
# ADBE    0.964025
# ADI     0.979251
# ADM     0.978034
# ADP     0.857370
# ADS     0.967198
# ADSK    0.996215
# ...
# WYN     0.977424
# WYNN    1.004447
# XEC     0.964945
# XEL     1.005280
# XL      1.004511
# XLNX    0.991383
# XOM     0.997803
# XRAY    0.989527
# XRX     0.986422
# XYL     0.991732
# YHOO    0.992866
# YUM     0.989095
# ZION    0.983452
# ZMH     1.004064
# ZTS     0.982178
# Length: 500, dtype: float64
